# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
all_2019 = pd.read_csv("CSB_2019-2020_All.csv")
# Out:
# C:\Users\Iurii Novachynskyi\AppData\Local\Temp\ipykernel_19444\2825453128.py:1: DtypeWarning: Columns (0,1,2,3,4,6,12,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_2019 = pd.read_csv("CSB_2019-2020_All.csv")

# %%
all_2021 = pd.read_csv("CSB_2021-2023_All.csv")
# Out:
# C:\Users\Iurii Novachynskyi\AppData\Local\Temp\ipykernel_3664\424796772.py:1: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_2021 = pd.read_csv("CSB_2021-2023_All.csv")

# %%
dd2 = all_2019.copy()

# %%
dd = all_2021.copy()

# %%
dd2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5615331 entries, 0 to 5615330
# Data columns (total 22 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   ride_id               object
#  1   rideable_type         object
#  2   started_at            object
#  3   ended_at              object
#  4   start_station_name    object
#  5   start_station_id      float64
#  6   end_station_name      object
#  7   end_station_id        float64
#  8   start_lat             float64
#  9   start_lng             float64
#  10  end_lat               float64
#  11  end_lng               float64
#  12  member_casual         object
#  13  Start_date            object
#  14  End_date              object
#  15  Start_station_number  int64
#  16  Start_station         object
#  17  End_station_number    int64
#  18  End_station           object
#  19  Member_type           object
#  20  Duration              float64
#  21  Bike_number           object
# ...

# %%
dd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8180626 entries, 0 to 8180625
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          object
#  3   ended_at            object
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: float64(4), object(9)
# memory usage: 811.4+ MB

# %%
dd2
# Out:
#                   ride_id rideable_type           started_at  \
# 0        77A0F1B26D1597B1   docked_bike  2020-04-25 17:28:39
# 1        8698F10128EA4F18   docked_bike  2020-04-06 07:54:59
# 2        AA07819DC0F58872   docked_bike  2020-04-22 17:06:18
# 3        DA909BCA92EF85AB   docked_bike  2020-04-16 15:22:40
# 4        B36F1E14D8C6757E   docked_bike  2020-04-10 13:19:41
# ...                   ...           ...                  ...
# 5615326               NaN           NaN                  NaN
# 5615327               NaN           NaN                  NaN
# 5615328               NaN           NaN                  NaN
# 5615329               NaN           NaN                  NaN
# 5615330               NaN           NaN                  NaN
#
#                     ended_at                 start_station_name  \
# 0        2020-04-25 17:35:04  Rhode Island & Connecticut Ave NW
# 1        2020-04-06 07:57:24                     21st & I St NW
# ...

# %%
dd[dd['rideable_type'] == 'electric_bike'].head(50)
# Out:
#               ride_id  rideable_type           started_at  \
# 1    629E059504606547  electric_bike  2021-01-01 00:13:43
# 2    E74069873161EE33  electric_bike  2021-01-01 00:14:32
# 5    0FD3B4B2152425C3  electric_bike  2021-01-01 00:18:16
# 7    78894BDABD9F21DD  electric_bike  2021-01-01 00:20:40
# 17   3F8AFD9540FF8EDB  electric_bike  2021-01-01 00:26:41
# 19   B0657CE2D8410E55  electric_bike  2021-01-01 00:26:54
# 20   997E8E08C493F034  electric_bike  2021-01-01 00:27:18
# 21   F1F87FA560990FC7  electric_bike  2021-01-01 00:28:39
# 22   87E06BFC439643DA  electric_bike  2021-01-01 00:32:44
# 24   6E4F247C2E3358BA  electric_bike  2021-01-01 00:35:51
# 27   1D12F2455A372283  electric_bike  2021-01-01 00:40:45
# 28   A4FB36E490BA300A  electric_bike  2021-01-01 00:40:52
# 33   53319771A46F4135  electric_bike  2021-01-01 00:45:05
# 37   60807578738CDEB8  electric_bike  2021-01-01 00:50:13
# 47   0A5B3D1015066666  electric_bike  2021-01-01 01:00:48
# ...

# %%
filtered_dd = dd[(dd['rideable_type'] == 'electric_bike') & (dd['end_station_name'].notna()) & (dd['start_station_name'].notna())]
filtered_dd.head(50)
# Out:
#                   ride_id  rideable_type           started_at  \
# 2        E74069873161EE33  electric_bike  2021-01-01 00:14:32
# 19       B0657CE2D8410E55  electric_bike  2021-01-01 00:26:54
# 27       1D12F2455A372283  electric_bike  2021-01-01 00:40:45
# 28       A4FB36E490BA300A  electric_bike  2021-01-01 00:40:52
# 56       9B229D84329221A6  electric_bike  2021-01-01 01:08:13
# ...                   ...            ...                  ...
# 8180603  328320C65CB36BA5  electric_bike  2023-06-30 23:54:10
# 8180604  6EED06CD2B385C89  electric_bike  2023-06-30 23:54:26
# 8180611  E2634220F8AEF94D  electric_bike  2023-06-30 23:55:26
# 8180613  C212963E29D612F0  electric_bike  2023-06-30 23:55:31
# 8180619  5BC09D5C797C1608  electric_bike  2023-06-30 23:56:52
#
#                     ended_at             start_station_name start_station_id  \
# 2        2021-01-01 00:28:45          17th & Corcoran St NW          31214.0
# ...

# %%
docked = dd[dd['rideable_type'] == 'docked_bike'].head()
docked
# Out:
#              ride_id rideable_type           started_at             ended_at  \
# 8   CB36F43FA77E4A35   docked_bike  2021-01-01 00:21:19  2021-01-01 00:33:31
# 18  6B4631D4B1BCB9BB   docked_bike  2021-01-01 00:26:51  2021-01-01 00:47:48
# 35  137C9E0ED6C16841   docked_bike  2021-01-01 00:47:55  2021-01-01 03:04:53
# 44  31584A6CEEE83CB7   docked_bike  2021-01-01 00:59:41  2021-01-01 01:27:52
# 45  7779B21BCBA77791   docked_bike  2021-01-01 00:59:44  2021-01-01 01:27:55
#
#                              start_station_name start_station_id  \
# 8                                15th & F St NE          31632.0
# 18  Henry Bacon Dr & Lincoln Memorial Circle NW          31289.0
# 35                               12th & L St NW          31251.0
# 44                                Thomas Circle          31241.0
# 45                                Thomas Circle          31241.0
#
#              end_station_name end_station_id  start_lat  start_lng    end_lat  \
# ...

# %%
zero_docked = (docked['start_station_name'] == 0).any()
zero_docked
# Out:
# False

# %%
dd['rideable_type'].value_counts() #2021-23
# Out:
# rideable_type
# classic_bike     6157609
# electric_bike    1521056
# docked_bike       501961
# Name: count, dtype: int64

# %%
dd2['rideable_type'].value_counts() #2019-20
# Out:
# rideable_type
# docked_bike      1391782
# electric_bike     239076
# classic_bike       48656
# Name: count, dtype: int64

# %%
electric = dd2['rideable_type'] ='electric_bike'

# %%
docked_bike_mask = dd2['rideable_type'] == 'docked_bike'
display(dd2[docked_bike_mask]['member_casual'].value_counts())
# Out:
# member_casual
# member    744844
# casual    646938
# Name: count, dtype: int64

# %%
dd2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Data Science CAB\PJ\PJ3 CapitalBikeshare\stations.ipynb Cell 17 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/Data%20Science%20CAB/PJ/PJ3%20CapitalBikeshare/stations.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> dd2
#
# NameError: name 'dd2' is not defined
