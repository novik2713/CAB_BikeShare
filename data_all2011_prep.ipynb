# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data11 = pd.read_csv("2011data\d2011.csv")

# %%
data121 = pd.read_csv('2011data\Q1.csv')
data122 = pd.read_csv('2011data\Q2.csv')
data123 = pd.read_csv('2011data\Q3.csv')
data124 = pd.read_csv('2011data\Q4.csv')

# %%
display(data121, data122, data123, data124)
# Out:
#         Duration           Start date             End date  \
# 0            475  2012-01-01 00:04:00  2012-01-01 00:11:56
# 1           1162  2012-01-01 00:10:05  2012-01-01 00:29:28
# 2           1145  2012-01-01 00:10:23  2012-01-01 00:29:28
# 3            485  2012-01-01 00:15:41  2012-01-01 00:23:46
# 4            471  2012-01-01 00:15:42  2012-01-01 00:23:34
# ...          ...                  ...                  ...
# 361312       634  2012-03-31 23:53:22  2012-04-01 00:03:56
# 361313       623  2012-03-31 23:53:38  2012-04-01 00:04:02
# 361314       658  2012-03-31 23:54:15  2012-04-01 00:05:14
# 361315       194  2012-03-31 23:56:18  2012-03-31 23:59:33
# 361316       140  2012-03-31 23:59:26  2012-04-01 00:01:46
#
#         Start station number                        Start station  \
# 0                      31245         7th & R St NW / Shaw Library
# 1                      31400       Georgia & New Hampshire Ave NW
# ...

# %%
data11
# Out:
#          Duration           Start date             End date  \
# 0            3548  2011-01-01 00:01:29  2011-01-01 01:00:37
# 1             346  2011-01-01 00:02:46  2011-01-01 00:08:32
# 2             562  2011-01-01 00:06:13  2011-01-01 00:15:36
# 3             434  2011-01-01 00:09:21  2011-01-01 00:16:36
# 4             233  2011-01-01 00:28:26  2011-01-01 00:32:19
# ...           ...                  ...                  ...
# 1226762       300  2011-12-31 23:41:19  2011-12-31 23:46:20
# 1226763       387  2011-12-31 23:46:43  2011-12-31 23:53:10
# 1226764       261  2011-12-31 23:47:27  2011-12-31 23:51:49
# 1226765      2060  2011-12-31 23:55:12  2012-01-01 00:29:33
# 1226766       468  2011-12-31 23:55:56  2012-01-01 00:03:45
#
#          Start station number                      Start station  \
# 0                       31620                      5th & F St NW
# 1                       31105               14th & Harvard St NW
# ...

# %%
data124.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 470845 entries, 0 to 470844
# Data columns (total 9 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Duration              470845 non-null  int64
#  1   Start date            470845 non-null  object
#  2   End date              470845 non-null  object
#  3   Start station number  470845 non-null  int64
#  4   Start station         470845 non-null  object
#  5   End station number    470845 non-null  int64
#  6   End station           470845 non-null  object
#  7   Bike number           470845 non-null  object
#  8   Member type           470845 non-null  object
# dtypes: int64(3), object(6)
# memory usage: 32.3+ MB

# %%
df = [data121, data122, data123, data124, data11]
all = pd.concat(df, ignore_index=True)

# %%
all['Start date'] = pd.to_datetime(all['Start date'])
all['End date'] = pd.to_datetime(all['End date'])
all['Time'] = all['End date'] - all['Start date']
all['Member type'] = all['Member type'].astype('category')

# %%
all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3255678 entries, 0 to 3255677
# Data columns (total 10 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Duration              int64
#  1   Start date            datetime64[ns]
#  2   End date              datetime64[ns]
#  3   Start station number  int64
#  4   Start station         object
#  5   End station number    int64
#  6   End station           object
#  7   Bike number           object
#  8   Member type           category
#  9   Time                  timedelta64[ns]
# dtypes: category(1), datetime64[ns](2), int64(3), object(3), timedelta64[ns](1)
# memory usage: 226.7+ MB

# %%
all.to_csv('all1112.csv', index=False)
